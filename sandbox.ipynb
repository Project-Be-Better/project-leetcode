# %%
counter_map = {}

for i in "sree":
    counter_map[i] = counter_map.get(i,0)+1 

for i in "eers":
    counter_map[i] = counter_map.get(i,0) -1

# %%
counter_map.values()
# Out:
# dict_values([0, 0, 0])
